# %% [markdown]
# ## Install sklearn

# %%
# !pip install scikit-learn pandas
# Out:
# Requirement already satisfied: scikit-learn in /Users/prabh/Projects/Cistra/.venv/lib/python3.13/site-packages (1.7.2)
# Requirement already satisfied: pandas in /Users/prabh/Projects/Cistra/.venv/lib/python3.13/site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.22.0 in /Users/prabh/Projects/Cistra/.venv/lib/python3.13/site-packages (from scikit-learn) (2.3.5)
# Requirement already satisfied: scipy>=1.8.0 in /Users/prabh/Projects/Cistra/.venv/lib/python3.13/site-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /Users/prabh/Projects/Cistra/.venv/lib/python3.13/site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/prabh/Projects/Cistra/.venv/lib/python3.13/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/prabh/Projects/Cistra/.venv/lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/prabh/Projects/Cistra/.venv/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/prabh/Projects/Cistra/.venv/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/prabh/Projects/Cistra/.venv/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %% [markdown]
# ## Load the dataset

# %%
import pandas as pd

df = pd.read_csv("/Users/prabh/Projects/Cistra/dataset/cost-of-living-processed.csv")
df.head()
# Out:
#                        City  meal_inexpensive  meal_midrange_2p  mcmeal  \
# 0  Saint Petersburg, Russia              7.34             29.35    4.40
# 1          Istanbul, Turkey              4.58             15.28    3.82
# 2             Izmir, Turkey              3.06             12.22    3.06
# 3         Helsinki, Finland             12.00             65.00    8.00
# 4         Chisinau, Moldova              4.67             20.74    4.15
#
#    beer_domestic  beer_imported_bottle  soda  water  milk  bread  ...  \
# 0           2.20                  2.20  0.76   0.53  0.98   0.71  ...
# 1           3.06                  3.06  0.64   0.24  0.71   0.36  ...
# 2           2.29                  2.75  0.61   0.22  0.65   0.38  ...
# 3           6.50                  6.75  2.66   1.89  0.96   2.27  ...
# 4           1.04                  1.43  0.64   0.44  0.68   0.33  ...
#
#    cappuccino  rice  tomatoes  bananas  onions   beef  car_price  pre_school  \
# 0        1.96  0.92      1.91     0.89    0.48   7.18   19305.29      411.83
# 1        1.84  1.30      0.80     1.91    0.62   9.73   20874.72      282.94
# 2        1.56  1.31      0.70     1.78    0.58   8.61   20898.83      212.18
# 3        3.87  2.13      2.91     1.61    1.25  12.34   24402.77      351.60
# 4        1.25  0.93      1.56     1.37    0.59   5.37   17238.13      210.52
#
#    avg_primary_school  median
# 0             5388.86    4.40
# 1             6905.43    3.82
# 2             4948.41    3.06
# 3             1641.00    8.00
# 4             2679.30    3.61
#
# [5 rows x 57 columns]

# %% [markdown]
# ## Show columns

# %%
df.columns
# Out:
# Index(['City', 'meal_inexpensive', 'meal_midrange_2p', 'mcmeal',
#        'beer_domestic', 'beer_imported_bottle', 'soda', 'water', 'milk',
#        'bread', 'eggs', 'cheese', 'water_large', 'wine',
#        'beer_domestic_bottle', 'beer_imported_bottle.1', 'cigarettes',
#        'ticket_oneway', 'chicken', 'monthly_pass', 'gasoline',
#        'volkswagen_golf', 'apt1_centre', 'apt1_outside', 'apt3_centre',
#        'apt3_outside', 'utilities', 'mobile_minute', 'avg_internet',
#        'fitness_club', 'tennis_court', 'cinema', 'jeans', 'summer_dress',
#        'nike_shoes', 'leather_shoes', 'sqm_buy_centre', 'sqm_buy_outside',
#        'salary', 'interest_rate', 'taxi_start', 'taxi_1km', 'taxi_wait',
#        'apples', 'oranges', 'potatoes', 'lettuce', 'cappuccino', 'rice',
#        'tomatoes', 'bananas', 'onions', 'beef', 'car_price', 'pre_school',
#        'avg_primary_school', 'median'],
#       dtype='object')

# %% [markdown]
# ## encode the cities

# %%
from sklearn.preprocessing import LabelEncoder

df = pd.get_dummies(df, columns=["City"], drop_first=False)

# %% [markdown]
# ## X and y

# %%
X = df.drop(columns=['median'])
y = df['median']

# %% [markdown]
# ## 70 - 30 % split for traning and testing

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, 
    y, 
    test_size=0.30,   # 30% testing
    random_state=42,  # keeps results consistent
    shuffle=True
)

print("Training size:", X_train.shape)
print("Testing size:", X_test.shape)
# Out:
# Training size: (112, 215)
# Testing size: (48, 215)

# %% [markdown]
# ## CATEGORY LISTS

# %%
# ----------------------------
# CATEGORY FEATURE GROUPS
# ----------------------------

food = [
    "meal_inexpensive", "meal_midrange_2p", "mcmeal",
    "bread", "eggs", "cheese", "milk",
    "water", "water_large",
    "apples", "oranges", "potatoes", "lettuce",
    "cappuccino", "rice", "tomatoes", "bananas", "onions",
    "chicken", "beef"
]

restaurants = [
    "meal_inexpensive", "meal_midrange_2p", "mcmeal",
    "beer_domestic", "beer_imported_bottle",
    "wine", "soda"
]

housing = [
    "apt1_centre", "apt1_outside",
    "apt3_centre", "apt3_outside",
    "sqm_buy_centre", "sqm_buy_outside",
    "utilities"
]

transport = [
    "ticket_oneway", "monthly_pass",
    "gasoline", "taxi_start", "taxi_1km", "taxi_wait"
]

internet_utils = [
    "avg_internet", "utilities"
]

lifestyle = [
    "jeans", "summer_dress", "nike_shoes", "leather_shoes",
    "cinema", "fitness_club", "tennis_court"
]

# %% [markdown]
# ## category averages per city

# %%
df['food_avg'] = df[food].mean(axis=1) * 2.0
df['restaurants_avg'] = df[restaurants].mean(axis=1) * 1.2
df['housing_avg'] = df[housing].mean(axis=1) * 3.0
df['transport_avg'] = df[transport].mean(axis=1) * 1.5
df['internet_utils_avg'] = df[internet_utils].mean(axis=1) * 1.0
df['lifestyle_avg'] = df[lifestyle].mean(axis=1) * 0.7

# %% [markdown]
# ## Ml Model

# %%
from sklearn.ensemble import RandomForestRegressor

model = RandomForestRegressor(
    n_estimators=900,        # more trees = smoother predictions
    max_depth=30,            # deeper tree learns structure better
    min_samples_split=3,     # default
    min_samples_leaf=1,      # default
    max_features="sqrt",     # improves generalization
    bootstrap=True,          # better stability
    random_state=42
)

model.fit(X_train, y_train)
print("Model trained successfully with improved parameters!")
# Out:
# Model trained successfully with improved parameters!

# %% [markdown]
# ## Evaluate Model

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
import numpy as np

y_pred = model.predict(X_test)


print("R2 Score:", r2_score(y_test, y_pred))
print("RMSE:", np.sqrt(mean_squared_error(y_test, y_pred)))
print("MAE:", mean_absolute_error(y_test, y_pred))
# Out:
# R2 Score: 0.9184101882494654
# RMSE: 0.6997181970630542
# MAE: 0.4693591531635836

# %% [markdown]
# ## Important features

# %%
import pandas as pd
import numpy as np

importances = model.feature_importances_
feature_names = X.columns

importance_df = pd.DataFrame({
    'Feature': feature_names,
    'Importance': importances
}).sort_values(by='Importance', ascending=False)

importance_df
# Out:
#                    Feature  Importance
# 2         meal_midrange_2p    0.085595
# 18                 chicken    0.076075
# 38                  salary    0.070933
# 16              cigarettes    0.067051
# 4            beer_domestic    0.065088
# 23            apt1_outside    0.061612
# 31                  cinema    0.056501
# 3                   mcmeal    0.055654
# 40              taxi_start    0.038336
# 1         meal_inexpensive    0.033650
# 22             apt1_centre    0.029011
# 48                    rice    0.027450
# 42               taxi_wait    0.026356
# 25            apt3_outside    0.025768
# 5     beer_imported_bottle    0.024152
# 17           ticket_oneway    0.020322
# 19            monthly_pass    0.019964
# 9                    bread    0.015298
# 47              cappuccino    0.013789
# 6                     soda    0.012683
# 46                 lettuce    0.011467
# 10                    eggs    0.011250
# 49                tomatoes    0.010868
# 24             apt3_centre    0.010374
# 52                    beef    0.009230
# 11                  cheese    0.008363
# 7                    water    0.007667
# 51                  onions    0.006527
# 41                taxi_1km    0.006467
# 54              pre_school    0.006419
# 12             water_large    0.006207
# 28            avg_internet    0.006044
# 37         sqm_buy_outside    0.005991
# 30            tennis_court    0.005276
# 13                    wine    0.004598
# 34              nike_shoes    0.004274
# 39           interest_rate    0.004240
# 32                   jeans    0.004171
# 43                  apples    0.004138
# 45                potatoes    0.004106
# 36          sqm_buy_centre    0.004012
# 55      avg_primary_school    0.003232
# 44                 oranges    0.003173
# 29            fitness_club    0.002947
# 35           leather_shoes    0.002379
# 14    beer_domestic_bottle    0.002350
# 8                     milk    0.002094
# 0                     City    0.002033
# 21         volkswagen_golf    0.002031
# 20                gasoline    0.001955
# 53               car_price    0.001928
# 50                 bananas    0.001925
# 27           mobile_minute    0.001813
# 15  beer_imported_bottle.1    0.001780
# 26               utilities    0.001724
# 33            summer_dress    0.001661

# %% [markdown]
# ## Selected features

# %%
selected_features = [
    'apt1_centre', 'apt1_outside', 'apt3_centre', 'apt3_outside',
    'sqm_buy_centre', 'sqm_buy_outside',
    'salary',
    'gasoline', 'monthly_pass', 'volkswagen_golf',
    'utilities', 'avg_internet', 'mobile_minute',
    'milk', 'bread', 'eggs', 'chicken', 'rice', 'cheese', 'beef',
    'potatoes', 'bananas', 'tomatoes',
    'pre_school', 'avg_primary_school',
    'City'
]

# %% [markdown]
# ## Build X again

# %%
X = df[selected_features]

# %% [markdown]
# ## Retrain

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.30, random_state=42
)

model = RandomForestRegressor(n_estimators=500, random_state=42)
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=500, random_state=42)

# %% [markdown]
# ## Install

# %%
pip install matplotlib seaborn
# Out:
# Requirement already satisfied: matplotlib in /Users/prabh/Projects/Cistra/.venv/lib/python3.13/site-packages (3.10.7)
# Requirement already satisfied: seaborn in /Users/prabh/Projects/Cistra/.venv/lib/python3.13/site-packages (0.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/prabh/Projects/Cistra/.venv/lib/python3.13/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/prabh/Projects/Cistra/.venv/lib/python3.13/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/prabh/Projects/Cistra/.venv/lib/python3.13/site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/prabh/Projects/Cistra/.venv/lib/python3.13/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in /Users/prabh/Projects/Cistra/.venv/lib/python3.13/site-packages (from matplotlib) (2.3.5)
# Requirement already satisfied: packaging>=20.0 in /Users/prabh/Projects/Cistra/.venv/lib/python3.13/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /Users/prabh/Projects/Cistra/.venv/lib/python3.13/site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in /Users/prabh/Projects/Cistra/.venv/lib/python3.13/site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/prabh/Projects/Cistra/.venv/lib/python3.13/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pandas>=1.2 in /Users/prabh/Projects/Cistra/.venv/lib/python3.13/site-packages (from seaborn) (2.3.3)
# Requirement already satisfied: pytz>=2020.1 in /Users/prabh/Projects/Cistra/.venv/lib/python3.13/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/prabh/Projects/Cistra/.venv/lib/python3.13/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/prabh/Projects/Cistra/.venv/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## BoxPlot

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(8,4))
sns.boxplot(x=df["median"])
plt.title("Outlier Analysis for Cost-of-living Score")
plt.show()

# %% [markdown]
# ## Find City

# %%
le.classes_.tolist().index("Istanbul")

# %% [markdown]
# ## Eva Again

# %% [markdown]
# ## city name

# %%
city_names = [c.replace("City_", "") for c in X.columns if c.startswith("City_")]

for name in city_names:
    print(name)
# Out:
# Abu Dhabi, United Arab Emirates
# Adelaide, Australia
# Ahmedabad, India
# Alexandria, Egypt
# Almaty, Kazakhstan
# Amman, Jordan
# Amsterdam, Netherlands
# Ankara, Turkey
# Athens, Greece
# Auckland, New Zealand
# Austin, TX, United States
# Baku, Azerbaijan
# Bangalore, India
# Bangkok, Thailand
# Banja Luka, Bosnia And Herzegovina
# Barcelona, Spain
# Beijing, China
# Beirut, Lebanon
# Belgrade, Serbia
# Berlin, Germany
# Bogota, Colombia
# Boston, MA, United States
# Brasov, Romania
# Bratislava, Slovakia
# Brisbane, Australia
# Brno, Czech Republic
# Brussels, Belgium
# Bucharest, Romania
# Budapest, Hungary
# Buenos Aires, Argentina
# Bursa, Turkey
# Cairo, Egypt
# Calgary, Canada
# Cape Town, South Africa
# Casablanca, Morocco
# Chandigarh, India
# Chennai, India
# Chicago, IL, United States
# Chisinau, Moldova
# Cluj-Napoca, Romania
# Colombo, Sri Lanka
# Copenhagen, Denmark
# Dallas, TX, United States
# Delhi, India
# Doha, Qatar
# Dubai, United Arab Emirates
# Dublin, Ireland
# Durban, South Africa
# Edmonton, Canada
# Eindhoven, Netherlands
# Frankfurt, Germany
# Gdansk, Poland
# Gothenburg, Sweden
# Guadalajara, Mexico
# Gurgaon, India
# Hamburg, Germany
# Hanoi, Vietnam
# Helsinki, Finland
# Ho Chi Minh City, Vietnam
# Hong Kong, Hong Kong
# Houston, TX, United States
# Hyderabad, India
# Iasi, Romania
# Istanbul, Turkey
# Izmir, Turkey
# Jakarta, Indonesia
# Jerusalem, Israel
# Johannesburg, South Africa
# Kathmandu, Nepal
# Kaunas, Lithuania
# Kharkiv, Ukraine
# Kiev, Ukraine
# Kolkata, India
# Krakow (Cracow), Poland
# Kuala Lumpur, Malaysia
# Las Vegas, NV, United States
# Lima, Peru
# Lisbon, Portugal
# Ljubljana, Slovenia
# Lodz, Poland
# London, United Kingdom
# Los Angeles, CA, United States
# Lviv, Ukraine
# Madrid, Spain
# Manila, Philippines
# Melbourne, Australia
# Mexico City, Mexico
# Milan, Italy
# Minsk, Belarus
# Monterrey, Mexico
# Montevideo, Uruguay
# Montreal, Canada
# Moscow, Russia
# Mumbai, India
# Munich, Germany
# Nairobi, Kenya
# New York, NY, United States
# Noida, India
# Novi Sad, Serbia
# Novosibirsk, Russia
# Odessa, Ukraine
# Oslo, Norway
# Ottawa, Canada
# Panama City, Panama
# Paris, France
# Perth, Australia
# Phoenix, AZ, United States
# Plovdiv, Bulgaria
# Podgorica, Montenegro
# Portland, OR, United States
# Porto, Portugal
# Poznan, Poland
# Prague, Czech Republic
# Pune, India
# Quito, Ecuador
# Reykjavik, Iceland
# Riga, Latvia
# Rome, Italy
# Rotterdam, Netherlands
# Saint Petersburg, Russia
# San Diego, CA, United States
# San Francisco, CA, United States
# San Jose, Costa Rica
# Santiago, Chile
# Santo Domingo, Dominican Republic
# Sao Paulo, Brazil
# Sarajevo, Bosnia And Herzegovina
# Seattle, WA, United States
# Seoul, South Korea
# Shanghai, China
# Singapore, Singapore
# Skopje, Macedonia
# Sofia, Bulgaria
# Stockholm, Sweden
# Sydney, Australia
# Taipei, Taiwan
# Tallinn, Estonia
# Tashkent, Uzbekistan
# Tbilisi, Georgia
# Tel Aviv-Yafo, Israel
# Thessaloniki, Greece
# Timisoara, Romania
# Tirana, Albania
# Tokyo, Japan
# Toronto, Canada
# Tunis, Tunisia
# Utrecht, Netherlands
# Valencia, Spain
# Vancouver, Canada
# Varna, Bulgaria
# Victoria, Canada
# Vienna, Austria
# Vilnius, Lithuania
# Warsaw, Poland
# Winnipeg, Canada
# Wroclaw, Poland
# Yekaterinburg, Russia
# Yerevan, Armenia
# Zagreb, Croatia
# Zurich, Switzerland

# %%
def predict_city(city_name):
    col = f"City_{city_name}"
    
    if col not in X.columns:
        print("City not found:", city_name)
        return
    
    # Find all rows for that city
    city_rows = X[X[col] == 1]

    # Predictions
    predicted = model.predict(city_rows).mean()
    actual = y.loc[city_rows.index].mean()

    print("City:", city_name)
    print("Predicted:", round(predicted, 3))
    print("Actual:", round(actual, 3))
    print("Error:", round(predicted - actual, 3))
    print("Error %:", round(abs(predicted - actual) / actual * 100, 3), "%")

# %%
city_columns = [c for c in X.columns if c.startswith("City_")]

for col in city_columns:
    # extract clean name
    city_name = col.replace("City_", "")
    predict_city(city_name)
    print("--------------------------------")
# Out:
# City: Abu Dhabi, United Arab Emirates
# Predicted: 7.306
# Actual: 7.34
# Error: -0.034
# Error %: 0.464 %
# --------------------------------
# City: Adelaide, Australia
# Predicted: 7.032
# Actual: 6.45
# Error: 0.582
# Error %: 9.024 %
# --------------------------------
# City: Ahmedabad, India
# Predicted: 3.244
# Actual: 3.16
# Error: 0.084
# Error %: 2.654 %
# --------------------------------
# City: Alexandria, Egypt
# Predicted: 3.395
# Actual: 3.38
# Error: 0.015
# Error %: 0.45 %
# --------------------------------
# City: Almaty, Kazakhstan
# Predicted: 3.688
# Actual: 3.58
# Error: 0.108
# Error %: 3.025 %
# --------------------------------
# City: Amman, Jordan
# Predicted: 6.203
# Actual: 6.34
# Error: -0.137
# Error %: 2.164 %
# --------------------------------
# City: Amsterdam, Netherlands
# Predicted: 8.14
# Actual: 8.0
# Error: 0.14
# Error %: 1.753 %
# --------------------------------
# City: Ankara, Turkey
# Predicted: 3.517
# Actual: 3.51
# Error: 0.007
# Error %: 0.203 %
# --------------------------------
# City: Athens, Greece
# Predicted: 6.72
# Actual: 7.06
# Error: -0.34
# Error %: 4.823 %
# --------------------------------
# City: Auckland, New Zealand
# Predicted: 7.742
# Actual: 7.54
# Error: 0.202
# Error %: 2.675 %
# --------------------------------
# City: Austin, TX, United States
# Predicted: 7.719
# Actual: 7.26
# Error: 0.459
# Error %: 6.326 %
# --------------------------------
# City: Baku, Azerbaijan
# Predicted: 3.643
# Actual: 3.54
# Error: 0.103
# Error %: 2.9 %
# --------------------------------
# City: Bangalore, India
# Predicted: 3.678
# Actual: 3.8
# Error: -0.122
# Error %: 3.223 %
# --------------------------------
# City: Bangkok, Thailand
# Predicted: 4.659
# Actual: 4.45
# Error: 0.209
# Error %: 4.706 %
# --------------------------------
# City: Banja Luka, Bosnia And Herzegovina
# Predicted: 3.797
# Actual: 3.58
# Error: 0.217
# Error %: 6.051 %
# --------------------------------
# City: Barcelona, Spain
# Predicted: 6.868
# Actual: 6.46
# Error: 0.408
# Error %: 6.323 %
# --------------------------------
# City: Beijing, China
# Predicted: 4.96
# Actual: 4.56
# Error: 0.4
# Error %: 8.768 %
# --------------------------------
# City: Beirut, Lebanon
# Predicted: 7.089
# Actual: 7.35
# Error: -0.261
# Error %: 3.553 %
# --------------------------------
# City: Belgrade, Serbia
# Predicted: 4.421
# Actual: 4.24
# Error: 0.181
# Error %: 4.27 %
# --------------------------------
# City: Berlin, Germany
# Predicted: 7.376
# Actual: 6.95
# Error: 0.426
# Error %: 6.134 %
# --------------------------------
# City: Bogota, Colombia
# Predicted: 3.65
# Actual: 3.3
# Error: 0.35
# Error %: 10.613 %
# --------------------------------
# City: Boston, MA, United States
# Predicted: 10.57
# Actual: 11.0
# Error: -0.43
# Error %: 3.908 %
# --------------------------------
# City: Brasov, Romania
# Predicted: 4.216
# Actual: 4.18
# Error: 0.036
# Error %: 0.868 %
# --------------------------------
# City: Bratislava, Slovakia
# Predicted: 5.378
# Actual: 5.33
# Error: 0.048
# Error %: 0.905 %
# --------------------------------
# City: Brisbane, Australia
# Predicted: 7.762
# Actual: 7.43
# Error: 0.332
# Error %: 4.468 %
# --------------------------------
# City: Brno, Czech Republic
# Predicted: 5.185
# Actual: 5.16
# Error: 0.025
# Error %: 0.493 %
# --------------------------------
# City: Brussels, Belgium
# Predicted: 8.107
# Actual: 8.2
# Error: -0.093
# Error %: 1.137 %
# --------------------------------
# City: Bucharest, Romania
# Predicted: 4.6
# Actual: 4.48
# Error: 0.12
# Error %: 2.674 %
# --------------------------------
# City: Budapest, Hungary
# Predicted: 4.809
# Actual: 4.79
# Error: 0.019
# Error %: 0.391 %
# --------------------------------
# City: Buenos Aires, Argentina
# Predicted: 4.149
# Actual: 4.12
# Error: 0.029
# Error %: 0.708 %
# --------------------------------
# City: Bursa, Turkey
# Predicted: 3.302
# Actual: 3.06
# Error: 0.242
# Error %: 7.908 %
# --------------------------------
# City: Cairo, Egypt
# Predicted: 3.476
# Actual: 3.38
# Error: 0.096
# Error %: 2.842 %
# --------------------------------
# City: Calgary, Canada
# Predicted: 8.943
# Actual: 9.53
# Error: -0.587
# Error %: 6.156 %
# --------------------------------
# City: Cape Town, South Africa
# Predicted: 4.65
# Actual: 4.36
# Error: 0.29
# Error %: 6.662 %
# --------------------------------
# City: Casablanca, Morocco
# Predicted: 4.369
# Actual: 4.45
# Error: -0.081
# Error %: 1.817 %
# --------------------------------
# City: Chandigarh, India
# Predicted: 3.37
# Actual: 3.3
# Error: 0.07
# Error %: 2.11 %
# --------------------------------
# City: Chennai, India
# Predicted: 3.245
# Actual: 3.16
# Error: 0.085
# Error %: 2.686 %
# --------------------------------
# City: Chicago, IL, United States
# Predicted: 9.677
# Actual: 9.95
# Error: -0.273
# Error %: 2.745 %
# --------------------------------
# City: Chisinau, Moldova
# Predicted: 3.737
# Actual: 3.61
# Error: 0.127
# Error %: 3.526 %
# --------------------------------
# City: Cluj-Napoca, Romania
# Predicted: 4.299
# Actual: 4.22
# Error: 0.079
# Error %: 1.871 %
# --------------------------------
# City: Colombo, Sri Lanka
# Predicted: 3.899
# Actual: 3.56
# Error: 0.339
# Error %: 9.516 %
# --------------------------------
# City: Copenhagen, Denmark
# Predicted: 8.867
# Actual: 8.7
# Error: 0.167
# Error %: 1.925 %
# --------------------------------
# City: Dallas, TX, United States
# Predicted: 7.144
# Actual: 6.51
# Error: 0.634
# Error %: 9.734 %
# --------------------------------
# City: Delhi, India
# Predicted: 3.665
# Actual: 3.8
# Error: -0.135
# Error %: 3.544 %
# --------------------------------
# City: Doha, Qatar
# Predicted: 7.7
# Actual: 8.09
# Error: -0.39
# Error %: 4.816 %
# --------------------------------
# City: Dubai, United Arab Emirates
# Predicted: 7.441
# Actual: 7.33
# Error: 0.111
# Error %: 1.51 %
# --------------------------------
# City: Dublin, Ireland
# Predicted: 8.267
# Actual: 8.35
# Error: -0.083
# Error %: 0.994 %
# --------------------------------
# City: Durban, South Africa
# Predicted: 4.422
# Actual: 3.94
# Error: 0.482
# Error %: 12.239 %
# --------------------------------
# City: Edmonton, Canada
# Predicted: 8.201
# Actual: 8.45
# Error: -0.249
# Error %: 2.943 %
# --------------------------------
# City: Eindhoven, Netherlands
# Predicted: 7.909
# Actual: 8.0
# Error: -0.091
# Error %: 1.137 %
# --------------------------------
# City: Frankfurt, Germany
# Predicted: 7.571
# Actual: 7.77
# Error: -0.199
# Error %: 2.56 %
# --------------------------------
# City: Gdansk, Poland
# Predicted: 4.385
# Actual: 4.25
# Error: 0.135
# Error %: 3.173 %
# --------------------------------
# City: Gothenburg, Sweden
# Predicted: 8.632
# Actual: 8.89
# Error: -0.258
# Error %: 2.897 %
# --------------------------------
# City: Guadalajara, Mexico
# Predicted: 4.241
# Actual: 4.25
# Error: -0.009
# Error %: 0.2 %
# --------------------------------
# City: Gurgaon, India
# Predicted: 3.69
# Actual: 3.8
# Error: -0.11
# Error %: 2.904 %
# --------------------------------
# City: Hamburg, Germany
# Predicted: 7.719
# Actual: 8.0
# Error: -0.281
# Error %: 3.506 %
# --------------------------------
# City: Hanoi, Vietnam
# Predicted: 3.57
# Actual: 3.36
# Error: 0.21
# Error %: 6.253 %
# --------------------------------
# City: Helsinki, Finland
# Predicted: 8.336
# Actual: 8.0
# Error: 0.336
# Error %: 4.197 %
# --------------------------------
# City: Ho Chi Minh City, Vietnam
# Predicted: 3.762
# Actual: 2.45
# Error: 1.312
# Error %: 53.559 %
# --------------------------------
# City: Hong Kong, Hong Kong
# Predicted: 7.315
# Actual: 6.82
# Error: 0.495
# Error %: 7.264 %
# --------------------------------
# City: Houston, TX, United States
# Predicted: 7.138
# Actual: 6.74
# Error: 0.398
# Error %: 5.908 %
# --------------------------------
# City: Hyderabad, India
# Predicted: 3.146
# Actual: 3.02
# Error: 0.126
# Error %: 4.158 %
# --------------------------------
# City: Iasi, Romania
# Predicted: 4.211
# Actual: 4.21
# Error: 0.001
# Error %: 0.013 %
# --------------------------------
# City: Istanbul, Turkey
# Predicted: 3.871
# Actual: 3.82
# Error: 0.051
# Error %: 1.344 %
# --------------------------------
# City: Izmir, Turkey
# Predicted: 3.482
# Actual: 3.06
# Error: 0.422
# Error %: 13.806 %
# --------------------------------
# City: Jakarta, Indonesia
# Predicted: 3.673
# Actual: 3.28
# Error: 0.393
# Error %: 11.971 %
# --------------------------------
# City: Jerusalem, Israel
# Predicted: 9.632
# Actual: 10.37
# Error: -0.738
# Error %: 7.119 %
# --------------------------------
# City: Johannesburg, South Africa
# Predicted: 4.919
# Actual: 4.59
# Error: 0.329
# Error %: 7.177 %
# --------------------------------
# City: Kathmandu, Nepal
# Predicted: 3.342
# Actual: 3.18
# Error: 0.162
# Error %: 5.082 %
# --------------------------------
# City: Kaunas, Lithuania
# Predicted: 4.912
# Actual: 5.07
# Error: -0.158
# Error %: 3.124 %
# --------------------------------
# City: Kharkiv, Ukraine
# Predicted: 3.637
# Actual: 3.75
# Error: -0.113
# Error %: 3.017 %
# --------------------------------
# City: Kiev, Ukraine
# Predicted: 4.13
# Actual: 3.75
# Error: 0.38
# Error %: 10.143 %
# --------------------------------
# City: Kolkata, India
# Predicted: 3.282
# Actual: 3.16
# Error: 0.122
# Error %: 3.846 %
# --------------------------------
# City: Krakow (Cracow), Poland
# Predicted: 4.603
# Actual: 4.72
# Error: -0.117
# Error %: 2.489 %
# --------------------------------
# City: Kuala Lumpur, Malaysia
# Predicted: 4.189
# Actual: 3.98
# Error: 0.209
# Error %: 5.25 %
# --------------------------------
# City: Las Vegas, NV, United States
# Predicted: 7.646
# Actual: 7.17
# Error: 0.476
# Error %: 6.638 %
# --------------------------------
# City: Lima, Peru
# Predicted: 4.592
# Actual: 4.3
# Error: 0.292
# Error %: 6.779 %
# --------------------------------
# City: Lisbon, Portugal
# Predicted: 5.571
# Actual: 5.23
# Error: 0.341
# Error %: 6.518 %
# --------------------------------
# City: Ljubljana, Slovenia
# Predicted: 5.872
# Actual: 6.0
# Error: -0.128
# Error %: 2.129 %
# --------------------------------
# City: Lodz, Poland
# Predicted: 4.406
# Actual: 4.25
# Error: 0.156
# Error %: 3.681 %
# --------------------------------
# City: London, United Kingdom
# Predicted: 8.124
# Actual: 7.87
# Error: 0.254
# Error %: 3.223 %
# --------------------------------
# City: Los Angeles, CA, United States
# Predicted: 9.46
# Actual: 9.48
# Error: -0.02
# Error %: 0.208 %
# --------------------------------
# City: Lviv, Ukraine
# Predicted: 3.674
# Actual: 3.6
# Error: 0.074
# Error %: 2.042 %
# --------------------------------
# City: Madrid, Spain
# Predicted: 6.9
# Actual: 6.23
# Error: 0.67
# Error %: 10.759 %
# --------------------------------
# City: Manila, Philippines
# Predicted: 4.233
# Actual: 3.13
# Error: 1.103
# Error %: 35.241 %
# --------------------------------
# City: Melbourne, Australia
# Predicted: 7.394
# Actual: 7.12
# Error: 0.274
# Error %: 3.846 %
# --------------------------------
# City: Mexico City, Mexico
# Predicted: 4.584
# Actual: 4.77
# Error: -0.186
# Error %: 3.899 %
# --------------------------------
# City: Milan, Italy
# Predicted: 8.04
# Actual: 8.0
# Error: 0.04
# Error %: 0.503 %
# --------------------------------
# City: Minsk, Belarus
# Predicted: 4.101
# Actual: 4.04
# Error: 0.061
# Error %: 1.521 %
# --------------------------------
# City: Monterrey, Mexico
# Predicted: 4.376
# Actual: 4.72
# Error: -0.344
# Error %: 7.281 %
# --------------------------------
# City: Montevideo, Uruguay
# Predicted: 6.375
# Actual: 6.96
# Error: -0.585
# Error %: 8.398 %
# --------------------------------
# City: Montreal, Canada
# Predicted: 8.765
# Actual: 8.94
# Error: -0.175
# Error %: 1.963 %
# --------------------------------
# City: Moscow, Russia
# Predicted: 5.172
# Actual: 6.6
# Error: -1.428
# Error %: 21.634 %
# --------------------------------
# City: Mumbai, India
# Predicted: 3.842
# Actual: 3.8
# Error: 0.042
# Error %: 1.112 %
# --------------------------------
# City: Munich, Germany
# Predicted: 7.698
# Actual: 7.59
# Error: 0.108
# Error %: 1.423 %
# --------------------------------
# City: Nairobi, Kenya
# Predicted: 5.03
# Actual: 4.6
# Error: 0.43
# Error %: 9.344 %
# --------------------------------
# City: New York, NY, United States
# Predicted: 10.787
# Actual: 13.48
# Error: -2.693
# Error %: 19.977 %
# --------------------------------
# City: Noida, India
# Predicted: 3.297
# Actual: 3.16
# Error: 0.137
# Error %: 4.327 %
# --------------------------------
# City: Novi Sad, Serbia
# Predicted: 4.064
# Actual: 4.04
# Error: 0.024
# Error %: 0.595 %
# --------------------------------
# City: Novosibirsk, Russia
# Predicted: 4.005
# Actual: 4.4
# Error: -0.395
# Error %: 8.988 %
# --------------------------------
# City: Odessa, Ukraine
# Predicted: 3.894
# Actual: 3.92
# Error: -0.026
# Error %: 0.671 %
# --------------------------------
# City: Oslo, Norway
# Predicted: 10.971
# Actual: 11.98
# Error: -1.009
# Error %: 8.421 %
# --------------------------------
# City: Ottawa, Canada
# Predicted: 8.435
# Actual: 9.04
# Error: -0.605
# Error %: 6.693 %
# --------------------------------
# City: Panama City, Panama
# Predicted: 6.111
# Actual: 6.06
# Error: 0.051
# Error %: 0.842 %
# --------------------------------
# City: Paris, France
# Predicted: 8.952
# Actual: 8.8
# Error: 0.152
# Error %: 1.729 %
# --------------------------------
# City: Perth, Australia
# Predicted: 7.612
# Actual: 7.32
# Error: 0.292
# Error %: 3.992 %
# --------------------------------
# City: Phoenix, AZ, United States
# Predicted: 7.535
# Actual: 7.38
# Error: 0.155
# Error %: 2.106 %
# --------------------------------
# City: Plovdiv, Bulgaria
# Predicted: 4.561
# Actual: 4.73
# Error: -0.169
# Error %: 3.578 %
# --------------------------------
# City: Podgorica, Montenegro
# Predicted: 4.476
# Actual: 4.89
# Error: -0.414
# Error %: 8.464 %
# --------------------------------
# City: Portland, OR, United States
# Predicted: 9.579
# Actual: 9.98
# Error: -0.401
# Error %: 4.021 %
# --------------------------------
# City: Porto, Portugal
# Predicted: 5.436
# Actual: 5.38
# Error: 0.056
# Error %: 1.033 %
# --------------------------------
# City: Poznan, Poland
# Predicted: 4.615
# Actual: 4.72
# Error: -0.105
# Error %: 2.22 %
# --------------------------------
# City: Prague, Czech Republic
# Predicted: 5.536
# Actual: 5.55
# Error: -0.014
# Error %: 0.254 %
# --------------------------------
# City: Pune, India
# Predicted: 3.541
# Actual: 3.54
# Error: 0.001
# Error %: 0.015 %
# --------------------------------
# City: Quito, Ecuador
# Predicted: 5.253
# Actual: 5.39
# Error: -0.137
# Error %: 2.55 %
# --------------------------------
# City: Reykjavik, Iceland
# Predicted: 10.254
# Actual: 11.64
# Error: -1.386
# Error %: 11.907 %
# --------------------------------
# City: Riga, Latvia
# Predicted: 5.156
# Actual: 5.0
# Error: 0.156
# Error %: 3.118 %
# --------------------------------
# City: Rome, Italy
# Predicted: 7.875
# Actual: 8.0
# Error: -0.125
# Error %: 1.569 %
# --------------------------------
# City: Rotterdam, Netherlands
# Predicted: 7.877
# Actual: 7.9
# Error: -0.023
# Error %: 0.287 %
# --------------------------------
# City: Saint Petersburg, Russia
# Predicted: 4.454
# Actual: 4.4
# Error: 0.054
# Error %: 1.217 %
# --------------------------------
# City: San Diego, CA, United States
# Predicted: 8.677
# Actual: 8.4
# Error: 0.277
# Error %: 3.299 %
# --------------------------------
# City: San Francisco, CA, United States
# Predicted: 10.378
# Actual: 12.11
# Error: -1.732
# Error %: 14.306 %
# --------------------------------
# City: San Jose, Costa Rica
# Predicted: 6.058
# Actual: 5.95
# Error: 0.108
# Error %: 1.813 %
# --------------------------------
# City: Santiago, Chile
# Predicted: 5.258
# Actual: 5.2
# Error: 0.058
# Error %: 1.122 %
# --------------------------------
# City: Santo Domingo, Dominican Republic
# Predicted: 4.834
# Actual: 5.1
# Error: -0.266
# Error %: 5.212 %
# --------------------------------
# City: Sao Paulo, Brazil
# Predicted: 4.944
# Actual: 6.13
# Error: -1.186
# Error %: 19.355 %
# --------------------------------
# City: Sarajevo, Bosnia And Herzegovina
# Predicted: 3.987
# Actual: 3.85
# Error: 0.137
# Error %: 3.562 %
# --------------------------------
# City: Seattle, WA, United States
# Predicted: 10.723
# Actual: 11.23
# Error: -0.507
# Error %: 4.511 %
# --------------------------------
# City: Seoul, South Korea
# Predicted: 6.745
# Actual: 6.7
# Error: 0.045
# Error %: 0.669 %
# --------------------------------
# City: Shanghai, China
# Predicted: 4.882
# Actual: 4.56
# Error: 0.322
# Error %: 7.061 %
# --------------------------------
# City: Singapore, Singapore
# Predicted: 7.949
# Actual: 8.33
# Error: -0.381
# Error %: 4.57 %
# --------------------------------
# City: Skopje, Macedonia
# Predicted: 4.346
# Actual: 4.58
# Error: -0.234
# Error %: 5.114 %
# --------------------------------
# City: Sofia, Bulgaria
# Predicted: 4.631
# Actual: 4.6
# Error: 0.031
# Error %: 0.666 %
# --------------------------------
# City: Stockholm, Sweden
# Predicted: 8.901
# Actual: 8.17
# Error: 0.731
# Error %: 8.947 %
# --------------------------------
# City: Sydney, Australia
# Predicted: 7.793
# Actual: 7.68
# Error: 0.113
# Error %: 1.471 %
# --------------------------------
# City: Taipei, Taiwan
# Predicted: 5.077
# Actual: 4.43
# Error: 0.647
# Error %: 14.616 %
# --------------------------------
# City: Tallinn, Estonia
# Predicted: 5.968
# Actual: 6.0
# Error: -0.032
# Error %: 0.534 %
# --------------------------------
# City: Tashkent, Uzbekistan
# Predicted: 3.548
# Actual: 2.7
# Error: 0.848
# Error %: 31.423 %
# --------------------------------
# City: Tbilisi, Georgia
# Predicted: 3.508
# Actual: 3.38
# Error: 0.128
# Error %: 3.791 %
# --------------------------------
# City: Tel Aviv-Yafo, Israel
# Predicted: 9.954
# Actual: 10.36
# Error: -0.406
# Error %: 3.924 %
# --------------------------------
# City: Thessaloniki, Greece
# Predicted: 6.281
# Actual: 6.5
# Error: -0.219
# Error %: 3.367 %
# --------------------------------
# City: Timisoara, Romania
# Predicted: 4.219
# Actual: 4.18
# Error: 0.039
# Error %: 0.922 %
# --------------------------------
# City: Tirana, Albania
# Predicted: 4.567
# Actual: 4.76
# Error: -0.193
# Error %: 4.061 %
# --------------------------------
# City: Tokyo, Japan
# Predicted: 7.165
# Actual: 6.58
# Error: 0.585
# Error %: 8.895 %
# --------------------------------
# City: Toronto, Canada
# Predicted: 9.835
# Actual: 10.31
# Error: -0.475
# Error %: 4.602 %
# --------------------------------
# City: Tunis, Tunisia
# Predicted: 3.294
# Actual: 3.19
# Error: 0.104
# Error %: 3.256 %
# --------------------------------
# City: Utrecht, Netherlands
# Predicted: 8.043
# Actual: 8.0
# Error: 0.043
# Error %: 0.54 %
# --------------------------------
# City: Valencia, Spain
# Predicted: 5.934
# Actual: 5.92
# Error: 0.014
# Error %: 0.237 %
# --------------------------------
# City: Vancouver, Canada
# Predicted: 9.895
# Actual: 10.31
# Error: -0.415
# Error %: 4.027 %
# --------------------------------
# City: Varna, Bulgaria
# Predicted: 4.436
# Actual: 4.5
# Error: -0.064
# Error %: 1.425 %
# --------------------------------
# City: Victoria, Canada
# Predicted: 8.95
# Actual: 8.83
# Error: 0.12
# Error %: 1.353 %
# --------------------------------
# City: Vienna, Austria
# Predicted: 7.435
# Actual: 7.25
# Error: 0.185
# Error %: 2.548 %
# --------------------------------
# City: Vilnius, Lithuania
# Predicted: 5.064
# Actual: 5.0
# Error: 0.064
# Error %: 1.279 %
# --------------------------------
# City: Warsaw, Poland
# Predicted: 4.772
# Actual: 4.72
# Error: 0.052
# Error %: 1.107 %
# --------------------------------
# City: Winnipeg, Canada
# Predicted: 8.425
# Actual: 8.94
# Error: -0.515
# Error %: 5.759 %
# --------------------------------
# City: Wroclaw, Poland
# Predicted: 4.691
# Actual: 4.72
# Error: -0.029
# Error %: 0.606 %
# --------------------------------
# City: Yekaterinburg, Russia
# Predicted: 4.059
# Actual: 3.87
# Error: 0.189
# Error %: 4.871 %
# --------------------------------
# City: Yerevan, Armenia
# Predicted: 4.137
# Actual: 4.29
# Error: -0.153
# Error %: 3.562 %
# --------------------------------
# City: Zagreb, Croatia
# Predicted: 5.431
# Actual: 5.37
# Error: 0.061
# Error %: 1.138 %
# --------------------------------
# City: Zurich, Switzerland
# Predicted: 11.623
# Actual: 12.94
# Error: -1.317
# Error %: 10.175 %
# --------------------------------

# %% [markdown]
# ## Error Find

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

# Predict on whole test set
y_pred = model.predict(X_test)

# Raw errors
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
mean_error = np.mean(y_pred - y_test)

# Multiply everything by 100
mae_100 = mae * 100
mse_100 = mse * 100
rmse_100 = rmse * 100
mean_error_100 = mean_error * 100

print("========== ERROR REPORT (×100) ==========")
print(f"MAE ×100:       {mae_100:.2f}")
print(f"MSE ×100:       {mse_100:.2f}")
print(f"RMSE ×100:      {rmse_100:.2f}")
print(f"Mean Error ×100:{mean_error_100:.2f}")
# Out:
# ========== ERROR REPORT (×100) ==========
# MAE ×100:       51.70
# MSE ×100:       51.57
# RMSE ×100:      71.81
# Mean Error ×100:1.98

# %% [markdown]
# ## Report

# %%
from sklearn.metrics import (
    r2_score,
    mean_squared_error,
    mean_absolute_error,
    median_absolute_error
)
import numpy as np

def regression_report(model, X_test, y_test):
    y_pred = model.predict(X_test)

    print("========== Regression Report ==========")
    print(f"R² Score:               {r2_score(y_test, y_pred):.4f}")
    print(f"MAE (Mean Abs Error):   {mean_absolute_error(y_test, y_pred):.4f}")
    print(f"RMSE (Root MSE):        {np.sqrt(mean_squared_error(y_test, y_pred)):.4f}")
    print(f"Median Abs Error:       {median_absolute_error(y_test, y_pred):.4f}")

    print("\nSample Predictions:")
    print("-------------------")
    for i in range(5):
        idx = X_test.sample(1).index[0]
        actual = y_test.loc[idx]
        pred = model.predict(X_test.loc[[idx]])[0]
        city_encoded = df.loc[idx, "City"]
        city_name = le.inverse_transform([city_encoded])[0]
        
        print(f"{city_name}: Pred = {round(pred, 3)}, Actual = {actual}")

# %% [markdown]
# # Run the report

# %%
regression_report(model, X_test, y_test)
# Out:
# ========== Regression Report ==========
# R² Score:               0.9145
# MAE (Mean Abs Error):   0.5168
# RMSE (Root MSE):        0.7162
# Median Abs Error:       0.4106
#
# Sample Predictions:
# -------------------
# Novosibirsk, Russia: Pred = 3.974, Actual = 4.4
# Manila, Philippines: Pred = 4.222, Actual = 3.13
# Edmonton, Canada: Pred = 8.059, Actual = 8.45
# Novosibirsk, Russia: Pred = 3.974, Actual = 4.4
# Krakow (Cracow), Poland: Pred = 4.613, Actual = 4.72

# %% [markdown]
# ## Save Model

# %%
import joblib

joblib.dump(model, "cost_of_living_model.pkl")
print("Model saved successfully!")
# Out:
# Model saved successfully!
